# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls '/content/drive/My Drive/helmet_detection'
# Out:
# backup	custom_weight  darknet	helmet	helmet.zip

# %%
# !unzip '/content/drive/My Drive/helmet_detection/helmet.zip' -d '/content/drive/My Drive/helmet_detection/'
# Out:
# Archive:  /content/drive/My Drive/helmet_detection/helmet.zip
#   inflating: /content/drive/My Drive/helmet_detection/helmet/_b879ee94-9ccf-11e6-a83e-3795272c0142.JPG
#   inflating: /content/drive/My Drive/helmet_detection/helmet/_b879ee94-9ccf-11e6-a83e-3795272c0142.txt
#   inflating: /content/drive/My Drive/helmet_detection/helmet/01HYMRM09-Helme+HY02HELMETTRAFFIC_C.jpg
#   inflating: /content/drive/My Drive/helmet_detection/helmet/01HYMRM09-Helme+HY02HELMETTRAFFIC_C.txt
#   inflating: /content/drive/My Drive/helmet_detection/helmet/02_10_0.jpg
#   inflating: /content/drive/My Drive/helmet_detection/helmet/02_10_0.txt
#   inflating: /content/drive/My Drive/helmet_detection/helmet/050ec9e401c2adc60d5f18a1618b7727__1.jpg
#   inflating: /content/drive/My Drive/helmet_detection/helmet/050ec9e401c2adc60d5f18a1618b7727__1.txt
#   inflating: /content/drive/My Drive/helmet_detection/helmet/08.jpg
#   inflating: /content/drive/My Drive/helmet_detection/helmet/08.txt
# ...

# %%
# !git clone 'https://github.com/AlexeyAB/darknet.git' '/content/drive/My Drive/helmet_detection/darknet'
# Out:
# Cloning into '/content/drive/My Drive/helmet_detection/darknet'...
# remote: Enumerating objects: 15412, done.
# remote: Total 15412 (delta 0), reused 0 (delta 0), pack-reused 15412
# Receiving objects: 100% (15412/15412), 14.05 MiB | 6.06 MiB/s, done.
# Resolving deltas: 100% (10354/10354), done.
# Checking out files: 100% (2050/2050), done.

# %%
# %cd '/content/drive/My Drive/helmet_detection/darknet'
# Out:
# /content/drive/My Drive/helmet_detection/darknet

# %%
# !make
# Out:
# chmod +x *.sh
# g++ -std=c++11 -std=c++11 -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/image_opencv.cpp -o obj/image_opencv.o
# ./src/image_opencv.cpp: In function ‘void draw_detections_cv_v3(void**, detection*, int, float, char**, image**, int, int)’:
# ./src/image_opencv.cpp:946:23: warning: variable ‘rgb’ set but not used [-Wunused-but-set-variable]
#                  float rgb[3];
#                        ^~~
# ./src/image_opencv.cpp: In function ‘void draw_train_loss(char*, void**, int, float, float, int, int, float, int, char*, float, int, int, double)’:
# ./src/image_opencv.cpp:1147:13: warning: this ‘if’ clause does not guard... [-Wmisleading-indentation]
#              if (iteration_old == 0)
#              ^~
# ...

# %%
# %cd '/content/drive/My Drive/helmet_detection'
# Out:
# /content/drive/My Drive/helmet_detection

# %%
# !python helmet/creating-files-data-and-name.py

# %%
# !python helmet/creating-train-and-test-txt-files.py

# %%
# !chmod 755 -R darknet

# %%
# !darknet/darknet detector train helmet/labelled_data.data darknet/cfg/yolov3_custom.cfg custom_weight/darknet53.conv.74 -dont_show
# Out:
# Streaming output truncated to the last 5000 lines.
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.807624), count: 4, class_loss = 0.323311, iou_loss = 0.170742, total_loss = 0.494052
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.609812), count: 4, class_loss = 0.797660, iou_loss = 0.476647, total_loss = 1.274307
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 0.000000, iou_loss = 0.000000, total_loss = 0.000000
#  total_bbox = 151912, rewritten_bbox = 0.000658 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.897807), count: 3, class_loss = 0.000729, iou_loss = 0.084022, total_loss = 0.084751
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.805207), count: 2, class_loss = 0.428782, iou_loss = 0.087548, total_loss = 0.516330
# ...
